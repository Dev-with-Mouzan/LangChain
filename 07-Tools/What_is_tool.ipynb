# %% [markdown]
# # What are Tool in LangChain
#
# Tools in LangChain are a way to extend the functionality of the LangChain engine. They are small, self-contained pieces of code that can be used to perform a specific task, such as generating code, writing documents, or creating chatbots.
#
# Tools can be used to augment the capabilities of the LangChain engine, and can be composed together to create more complex workflows. They are typically small language models that are fine-tuned on the specific task of generating code based on human instructions.
#
# There are several types of Tools in LangChain, including:
#
# * **Code Generation Tools**: These are tools that are responsible for generating code based on human instructions, such as generating code based on human instructions, or generating code based on human instructions.
# * **Document Generation Tools**: These are tools that are responsible for generating documents based on human instructions, such as generating documents based on human instructions, or generating documents based on human instructions.
# * **Chat Generation Tools**: These are tools that are responsible for generating chat based on human instructions, such as generating chat based on human instructions, or generating chat based on human instructions.
#
# Tools are a powerful tool in LangChain, and can be used to create complex workflows and generate code based on human instructions.

# %% [markdown]
# Some examples of Tools in LangChain include:
#
# * **Code Generation Tools**:
# 	+ **Google Code Search Tool**: This tool is responsible for generating code based on human instructions using Google Code Search.
# 	+ **Stack Overflow Tool**: This tool is responsible for generating code based on human instructions using Stack Overflow.
# * **Document Generation Tools**:
# 	+ **Google Docs Tool**: This tool is responsible for generating documents based on human instructions using Google Docs.
# 	+ **Microsoft Word Tool**: This tool is responsible for generating documents based on human instructions using Microsoft Word.
# * **Chat Generation Tools**:
# 	+ **Dialogflow Tool**: This tool is responsible for generating chat based on human instructions using Dialogflow.
# 	+ **Rasa Tool**: This tool is responsible for generating chat based on human instructions using Rasa.
